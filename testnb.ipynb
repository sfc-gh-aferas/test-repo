# %%
import sys
from snowflake.snowpark import Session

n = int(sys.argv[2]) + 2

with open("test7.txt","w") as f:
    f.write(str(n))

session = Session.get_active_session()
session.file.put("test7.txt","@ml_dev_db.public.nbstage", auto_compress=False,overwrite=True)
